# %%
#image to string conversion
import base64
import pyaes, pbkdf2, binascii, os, secrets

path=input("Enter path for the image")
with open(path, "rb") as image2string:
    converted_string = base64.b64encode(image2string.read())
print(type(converted_string))
plain_text = converted_string

# Derive a 256-bit AES encryption key from the password
password ="aklskdlakdlsak"
passwordSalt = os.urandom(128)
key = pbkdf2.PBKDF2(password, passwordSalt).read(32)
print(key)
print('AES encryption key:', binascii.hexlify(key))

iv = secrets.randbits(256)
aes = pyaes.AESModeOfOperationCTR(key, pyaes.Counter(iv))
ciphertext = aes.encrypt(plain_text)
print(base64.b64encode(ciphertext))
# ciphertext=base64.b64encode(ciphertext)

print('Encrypted:',(ciphertext))
  
with open('image_string.bin', "wb") as file:
    file.write(ciphertext)
# Out:
# Enter path for the imagedp.jpeg
# <class 'bytes'>
# b'\x95\xafZ\x91\xbc;\x87\xea\xc3N=/\xdemf\x0f\x14\xc4\xb3?\xe4\x9c\xa8!\x92\x856\r6\x11(\x8e'
# AES encryption key: b'95af5a91bc3b87eac34e3d2fde6d660f14c4b33fe49ca8219285360d3611288e'
# b'...'
# Encrypted: b'k\xabL=\x96\x93\x14\x1b8U\xeb\xebq\x87\x95Mj\xb1\x96\x94!\xbcH\xa1-\xfb\xc9/\xa9@\xcf\xa1fRu\xed\x8f\xaaN{\xc18M\xdf8\xe9\xcb\x01\xee\xff\xb6\r\x05r] L\xf7Kn\xb5\xdf\xf7\xe8\x8eA:\xcdYEg\x1bY\xb2\xf8\xc5G\xbf\xad\xa7\xfc>\x02\x9b\xe6\x1b\x08\x06\rS\xcb\x00\x18\x84+\xbel\r\xaf\xd5\xfa\x86}\xd2y\x91\x85\xd5\x1c\x90\xdfe\xeb\xfa\x13\xaf\x02\x92\xa7\x1a\xa2\x8a\xe3\x8f\xfa^\x83,\\\x934\xda\xb9\x91\x14\x00\xf9\x9e\x95\x1dD)\x19\xf9\rnb\x90n\x02\xfb\xd5\xb9\xe0\\\xc8jP/\xc9\xc9k0\xe4tZ\x0cR\xcbdW`M\xf4\xe3\x1by\xd1\x14C\x9e$k\xf8\x85^\xe6\xc6s\xa8\xc3\xac\x01\xdde\xfa\x07)\x13\x18\x17\x13S\x8cP\xcbP&McW\xee\x06\x06\x7f\xc4\xbd\xf5\xfd\x7f\xa2\xaa\x9a\xf8k\xd7\xe3M\xb3\xb6\xbb0\xac\x0b(\xa7[\xa9\x97R\x1a\xf0\xca\xd3\t\xa48\xa7\xca\xbb\x977m\xb3\xb4\x86l\xe3\xe7x/\xfc2\x8c&\xf3\xd4\xf8\x18\x98~\xad+\xf25i\xcb\x93K\xc2J6U\xfcF\xbcj}\xfc\xb1S"\xc3\xdb>\xd1\xd9\xa0\xf2/\x9f\xae#\x93\xfc\xcd&C\xfc}IE,\xe9\x8f\xc5\xc7\xf7PE\n\xfe*+!\xe0\x19\xa4\xa3\xfd4\x0b\xd4\xd8\xdc\x90\x14C\x9a\x0e{ \x19Z\xd4\xfb\x14\xc3\x0f\x03-?4\xe3\xb0\xad\xc0\xc0\x18\xa9H\xa8\xb8-O\xbcUK\xaa\xe5\x8b\xd3\r\xbaZ\xa9\xfd\xf0g\x8a\x1eu\x1e\xd7Jg\x85\xfc\x12I@/u%\xe63\x9b&\xf3\xa6\xc9\xcb,f\xc9\xae\xed\xf0E\xac0\r\x8c%\xd0\x14
\x95\x8d\xd5\xcb\x9f\x16\xab\xbc0\xfa\xf7\xe0\xa0\x16O7\xeb8!\xben9\xc8:XA\xc4\x12\x9d\xccwJO\xc7\xf3\xc9d!\x11\x81\xcf\x9dd\xa5\x07\\\x07\'2\xf7p\xe0\xa4Fa"\xf9\x8bL\xaa\xc0\xaa\xb8\x9c\xaf\x8a\x89\x7f\x04\x01{\xe8\xed$\xd2\xe1\xbcfj(B3\xb5\xb3kN\x10eP$r\xc7\xdf\xf5.\xed\xe7\xee5\x11g\x9dx\x8co:I\x01\xeb\x84\x1e\xc6\xea\xa3e\x112}\xde\x9a \xc0\xdd;\x84l|-\x85\xd1\xad\xd03\xeb\x96\xd35`\x8ccd\xaf\xa6\x93\x82\xf0q\x8d8\x18";\x0e\xe2t\xd4\xc3\xbf\xfad\x19\x06\xa5\xb9\x9e\xd0\xcb\x05(/\xa5\r\x86?Gl>Y\xff|\xdf\x7fr\xed\x89\x05\xeb\xb0\xad+y}3\xa2d\xc3\xe3\xf4X\xc4\xcc0\xbd\x03*U\xa7,S\xa2\x8a\xf8\xe5\x8f(P\xfb.\x0e\xd8\x95\x89\x0e\x9c:\xc4\x8f\xed+\xc9$\x99\xac\xa6\x19`\xaf\xdaO+\x08j\xb8\xf0_\xbclZ\xa0\x1e\xed*\r\xa0\xc5\xd3M\x16\xe7p\xd9q\xf6IB\x8b\x99V"\xbb\xfeZ\xbe?\xc0\xadK\x94&\xc0\xe0wN\xb1\x01L[l\xe85&\x93\xb2\x0bh\xa0\xf5\xa3\xe5\x84\xd4\xbfn\xf2q\x9e\x9f\xe4vb\xbdLl|.\xb9\xcc\x0c\xe1\xc05\xa0H:\x9dG\xb2v\x93\xea\x90x\xf7\\\xa3+\xd9\xb6Y\xd4 ...

# %%
from pathlib import Path
file = open('image_string.bin', 'rb')
byte = file.read()
file.close()
print(iv)
aes = pyaes.AESModeOfOperationCTR(key, pyaes.Counter(iv))
decrypted = aes.decrypt(byte)

# print(decrypted)
# print(base64.b64decode((decrypted)))

downloads_path = str(Path.home() /"Downloads")
print(downloads_path)
save=downloads_path+'\image4.jpeg'
decodeit = open(r''+save, 'wb')
decodeit.write(base64.b64decode((decrypted)))
decodeit.close()
# Out:
# 9247453396213462203453487846470536980857300758405104645871472682532674991353
# C:\Users\adity\Downloads

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-56-66eb25157f95> in <module>
#       6 # aes = pyaes.AESModeOfOperationCTR(key, pyaes.Counter(iv))
#       7 # decrypted = aes.decrypt(byte)
# ----> 8 byte=byte.decode('utf-8').strip()
#       9 # print(decrypted)
#      10 # print(base64.b64decode((decrypted)))
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbc in position 0: invalid start byte

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-66-f1784f5c5478> in <module>
#       1 import os
# ----> 2 from twilio.rest import Client
#       3
#       4
#       5 # Find your Account SID and Auth Token at twilio.com/console
#
# ModuleNotFoundError: No module named 'twilio'

# %%
# Out:
# Collecting twilio
#   Downloading twilio-7.14.2-py2.py3-none-any.whl (1.4 MB)
# Collecting PyJWT<3.0.0,>=2.0.0
#   Downloading PyJWT-2.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\adity\anaconda3\lib\site-packages (from twilio) (2.24.0)
# Requirement already satisfied: pytz in c:\users\adity\anaconda3\lib\site-packages (from twilio) (2020.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\adity\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\adity\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\adity\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adity\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2022.6.15)
# Installing collected packages: PyJWT, twilio
# Successfully installed PyJWT-2.5.0 twilio-7.14.2
